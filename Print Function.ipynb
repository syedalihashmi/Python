# %%
print(123)   #integers
# Out:
# 123

# %%
print("hello world 1")
print("hello world 2")
print("hello world 3")
# Out:
# hello world 1
# hello world 2
# hello world 3

# %%
print("hello world 1" , end="\n")     #escape  character
print("hello world 2" , end="\n")
print("hello world 3" , end="\n")
# Out:
# hello world 1
# hello world 2
# hello world 3

# %%
print("hello world 1" , end="\t")     #escape character
print("hello world 2" , end="\t")
print("hello world 3" , end="\t")
# Out:
# hello world 1	hello world 2	hello world 3

# %%
print("hello world 1" , end="\r")     #escape character
print("hello world 2" , end="\r")
print("hello world 3" , end="\r")
# Out:
# hello world 3

# %%
print("hello world 1" , end="\$\n\t")     #escape character
print("hello world 2" , end="\$\n\t")
print("hello world 3" , end="\$\n\t")
# Out:
# hello world 1\$
# 	hello world 2\$
# 	hello world 3\$
